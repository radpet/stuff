# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5243, 3081, 12, 6, 195, 2, 3134, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'originated', 'a', 'term', 'as', 'a', 'of']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['anarchism', 'term', 'a', 'originated', 'term', 'of', 'originated', 'as']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(),tf.device('/cpu:0'): #cpu is faster

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
def train_skip():
    num_steps = 100001

    with tf.Session(graph=graph) as session:
      tf.global_variables_initializer().run()
      print('Initialized')
      average_loss = 0
      for step in range(num_steps):
        batch_data, batch_labels = generate_batch(
          batch_size, num_skips, skip_window)
        feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
        _, l = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += l
        if step % 2000 == 0:
          if step > 0:
            average_loss = average_loss / 2000
          # The average loss is an estimate of the loss over the last 2000 batches.
          print('Average loss at step %d: %f' % (step, average_loss))
          average_loss = 0
        # note that this is expensive (~20% slowdown if computed every 500 steps)
        if step % 10000 == 0:
          sim = similarity.eval()
          for i in range(valid_size):
            valid_word = reverse_dictionary[valid_examples[i]]
            top_k = 8 # number of nearest neighbors
            nearest = (-sim[i, :]).argsort()[1:top_k+1]
            log = 'Nearest to %s:' % valid_word
            for k in range(top_k):
              close_word = reverse_dictionary[nearest[k]]
              log = '%s %s,' % (log, close_word)
            print(log)
      return normalized_embeddings.eval()
final_embeddings = train_skip()
# Out:
# Initialized
# Average loss at step 0: 7.414632
# Nearest to would: zip, orders, demon, neuroscience, mcdonnell, mensheviks, scrolls, cline,
# Nearest to see: depict, incorporated, diverting, legion, manually, revelation, nam, tay,
# Nearest to between: beno, conducts, ever, inquart, ganga, leonardo, ufc, completing,
# Nearest to its: plurality, buggy, jewel, envelopes, hyphens, exerts, final, deadweight,
# Nearest to such: picking, opposes, part, warners, beau, husband, ferocity, tt,
# Nearest to zero: targ, sinti, console, unenforceable, louise, hcl, gpmg, orbits,
# Nearest to have: cremona, analogues, bona, synchronisation, prognosis, crank, delved, croatian,
# Nearest to during: chubut, maclachlan, extreme, structuring, ngel, whereby, interacted, overseers,
# Nearest to had: italiano, satirist, dylan, standardisation, norsk, sufficiently, dactyl, electroplating,
# Nearest to history: sea, peres, untso, events, placenta, crystallographic, abbreviation, marshals,
# Nearest to may: mancala, mathematics, pedophilia, downward, sbs, chadwick, integration, chiba,
# Nearest to new: kliper, gretzky, pull, lowe, kirlian, xxxii, boilers, ige,
# Nearest to they: stony, avenue, parodying, scales, gana, alaskans, thunderbolt, eugenie,
# Nearest to by: heroes, didgeridoo, exemplified, picker, phospholipid, sucrose, retaliatory, geographic,
# Nearest to were: classificatory, ogden, dew, inciting, patrimony, kota, hmas, secretive,
# Nearest to been: chance, jagiellonian, matrix, valois, reorganizing, abstained, brushes, hansen,
# Average loss at step 2000: 4.368375
# Average loss at step 4000: 3.862844
# Average loss at step 6000: 3.794644
# Average loss at step 8000: 3.691419
# Average loss at step 10000: 3.613450
# Nearest to would: can, could, may, charges, behold, roshan, legitimate, ei,
# Nearest to see: depict, channel, incorporated, nam, diverting, airfoil, consist, manually,
# Nearest to between: completing, cowardly, with, beno, ever, butcher, siemens, approving,
# Nearest to its: the, their, his, envelopes, expanding, vestigial, rogers, ker,
# Nearest to such: opposes, garter, campuses, tissue, well, amraam, imitative, preference,
# Nearest to zero: eight, five, seven, nine, six, four, three, two,
# Nearest to have: had, has, be, were, are, been, infantry, cremona,
# Nearest to during: whereby, primers, maclachlan, extreme, chubut, structuring, wroc, macrobiotics,
# Nearest to had: has, have, was, blames, did, buoyancy, although, girolamo,
# Nearest to history: peres, sea, crystallographic, events, untso, antiprisms, hanoi, island,
# Nearest to may: can, must, would, dma, baxter, mancala, intensify, capuchin,
# Nearest to new: portraiture, kirlian, boilers, pull, gretzky, goya, lyc, character,
# Nearest to they: he, not, there, she, it, we, avenue, alloy,
# Nearest to by: retaliatory, was, festivities, were, on, as, temperate, first,
# Nearest to were: are, was, have, wily, slovakian, by, is, mole,
# Nearest to been: presley, be, valois, have, malays, jagiellonian, kirsten, matrix,
# Average loss at step 12000: 3.604090
# Average loss at step 14000: 3.570825
# Average loss at step 16000: 3.413444
# Average loss at step 18000: 3.455139
# Average loss at step 20000: 3.543778
# Nearest to would: can, could, may, will, might, should, legitimate, to,
# Nearest to see: depict, incorporated, cardiomyopathy, but, ramen, compact, derailed, reactionary,
# Nearest to between: with, reeves, xenon, cowardly, butcher, efficacious, completing, in,
# Nearest to its: their, the, his, envelopes, this, some, ifrcs, slater,
# Nearest to such: well, these, anyone, tissue, related, opposes, ceos, garter,
# Nearest to zero: five, six, seven, eight, four, three, nine, two,
# Nearest to have: had, has, be, were, are, nicaragua, octahedron, hoffer,
# Nearest to during: whereby, extreme, melito, shuts, maclachlan, primers, following, at,
# Nearest to had: has, have, was, were, girolamo, been, vistula, did,
# Nearest to history: peres, sea, island, voice, crystallographic, marshals, events, untso,
# Nearest to may: can, would, must, might, will, should, cannot, amerindian,
# Nearest to new: portraiture, gretzky, kirlian, character, lyc, pull, ifrcs, eduard,
# Nearest to they: he, there, we, it, she, who, not, these,
# Nearest to by: retaliatory, from, were, with, festivities, through, be, was,
# Nearest to were: are, was, had, have, while, by, is, ltc,
# Nearest to been: be, was, valois, had, malays, presley, never, specie,
# Average loss at step 22000: 3.503093
# Average loss at step 24000: 3.487503
# Average loss at step 26000: 3.486281
# Average loss at step 28000: 3.477343
# Average loss at step 30000: 3.502870
# Nearest to would: could, can, may, will, should, must, might, does,
# Nearest to see: depict, but, derailed, cardiomyopathy, list, carr, reactionary, incorporated,
# Nearest to between: with, reeves, xenon, from, beno, cowardly, electroplating, pilsner,
# Nearest to its: their, the, his, her, envelopes, freedom, occasion, some,
# Nearest to such: well, these, other, yahya, ceos, known, gray, many,
# Nearest to zero: five, seven, eight, four, six, nine, three, two,
# Nearest to have: had, has, were, are, be, include, nicaragua, viscount,
# Nearest to during: after, in, at, whereby, before, shuts, when, around,
# Nearest to had: has, have, was, were, girolamo, interpolating, beginnings, is,
# Nearest to history: island, peres, hanoi, basenji, capital, umayyad, polymerization, terminals,
# Nearest to may: can, would, must, will, might, should, could, cannot,
# Nearest to new: portraiture, lyc, eduard, undermines, second, kirlian, gretzky, ifrcs,
# Nearest to they: he, there, we, she, who, it, these, you,
# Nearest to by: under, were, brady, and, in, was, mascarenhas, exemplified,
# Nearest to were: are, was, have, had, been, those, by, while,
# Nearest to been: be, become, was, were, malays, never, specie, valois,
# Average loss at step 32000: 3.504370
# Average loss at step 34000: 3.499265
# Average loss at step 36000: 3.457743
# Average loss at step 38000: 3.301644
# Average loss at step 40000: 3.432467
# Nearest to would: could, will, can, may, should, might, must, did,
# Nearest to see: depict, but, list, reactionary, derailed, coerced, neptune, cardiomyopathy,
# Nearest to between: reeves, with, within, xenon, electroplating, through, pilsner, into,
# Nearest to its: their, his, the, her, blueprint, baiting, polygons, reorganized,
# Nearest to such: well, these, known, follows, yahya, many, part, related,
# Nearest to zero: five, seven, nine, six, eight, four, three, metres,
# Nearest to have: had, has, were, are, be, minors, include, nicaragua,
# Nearest to during: before, after, until, first, shuts, from, at, against,
# Nearest to had: has, have, was, were, pillaged, girolamo, monophyletic, been,
# Nearest to history: island, lighthouse, peres, gro, osage, untso, goal, sacred,
# Nearest to may: can, will, would, must, might, should, could, cannot,
# Nearest to new: portraiture, gretzky, second, bench, eduard, hoist, retroactively, ifrcs,
# Nearest to they: we, there, he, it, you, she, these, not,
# Nearest to by: didgeridoo, dispelling, was, autres, with, be, as, when,
# Nearest to were: are, was, have, while, been, had, be, those,
# Nearest to been: become, be, were, was, malays, being, specie, scarce,
# Average loss at step 42000: 3.437613
# Average loss at step 44000: 3.450842
# Average loss at step 46000: 3.451411
# Average loss at step 48000: 3.355045
# Average loss at step 50000: 3.381026
# Nearest to would: could, will, can, may, should, must, might, did,
# Nearest to see: depict, list, but, hautes, drinkordie, according, neptune, include,
# Nearest to between: with, through, within, electroplating, xenon, reeves, among, pilsner,
# Nearest to its: their, his, the, her, baiting, blueprint, utraquists, envelopes,
# Nearest to such: well, these, known, many, follows, related, zirconium, mae,
# Nearest to zero: five, seven, eight, four, six, nine, two, three,
# Nearest to have: had, has, were, are, be, nicaragua, minors, stratofortress,
# Nearest to during: after, in, before, until, at, first, throughout, from,
# Nearest to had: has, have, was, having, were, situational, girolamo, did,
# Nearest to history: island, screenings, goal, peres, sacred, osage, pai, sdk,
# Nearest to may: can, would, must, will, should, might, could, cannot,
# Nearest to new: second, portraiture, bench, tarnished, lysosome, unfairness, eduard, musical,
# Nearest to they: we, there, he, she, it, you, these, i,
# Nearest to by: was, through, in, under, during, brady, saipan, cossiga,
# Nearest to were: are, have, was, had, be, been, those, these,
# Nearest to been: become, be, was, were, specie, crooked, scarce, had,
# Average loss at step 52000: 3.436984
# Average loss at step 54000: 3.424399
# Average loss at step 56000: 3.439347
# Average loss at step 58000: 3.400954
# Average loss at step 60000: 3.394621
# Nearest to would: could, will, can, may, should, must, might, cannot,
# Nearest to see: but, list, depict, include, includes, including, can, expectancies,
# Nearest to between: with, within, among, through, xenon, reeves, in, into,
# Nearest to its: their, his, the, her, baiting, blueprint, utraquists, polygons,
# Nearest to such: well, these, known, many, follows, mae, cowardly, seen,
# Nearest to zero: five, four, six, seven, eight, three, nine, two,
# Nearest to have: has, had, were, are, be, include, having, situational,
# Nearest to during: after, before, in, although, until, throughout, following, when,
# Nearest to had: has, have, was, having, were, did, situational, been,
# Nearest to history: island, list, classical, danube, bellamy, osage, author, quadrangle,
# Nearest to may: can, would, will, must, should, might, could, cannot,
# Nearest to new: eduard, portraiture, bench, tarnished, unfairness, condemnation, lysosome, second,
# Nearest to they: we, there, he, you, she, it, these, i,
# Nearest to by: through, didgeridoo, dispelling, without, was, chu, guppy, affect,
# Nearest to were: are, was, while, have, had, those, be, although,
# Nearest to been: become, be, was, were, had, previously, reassert, crooked,
# Average loss at step 62000: 3.243045
# Average loss at step 64000: 3.259211
# Average loss at step 66000: 3.405361
# Average loss at step 68000: 3.398253
# Average loss at step 70000: 3.362965
# Nearest to would: will, could, can, may, should, must, might, cannot,
# Nearest to see: include, depict, list, rias, but, drinkordie, and, according,
# Nearest to between: within, among, with, reeves, through, xenon, destructive, anti,
# Nearest to its: their, the, his, her, baiting, divisive, utraquists, liberties,
# Nearest to such: these, well, known, many, follows, some, mae, certain,
# Nearest to zero: five, six, seven, eight, four, three, nine, two,
# Nearest to have: had, has, were, are, include, electroplating, having, be,
# Nearest to during: after, before, in, throughout, until, following, despite, although,
# Nearest to had: have, has, was, were, having, situational, been, since,
# Nearest to history: list, osage, basenji, classical, doctrine, quadrangle, groningen, danube,
# Nearest to may: can, will, would, must, might, should, could, cannot,
# Nearest to new: queensland, unfairness, pull, duchy, abound, bench, gretzky, eduard,
# Nearest to they: we, he, there, you, it, she, stemmed, then,
# Nearest to by: through, didgeridoo, afar, ls, paigc, using, in, be,
# Nearest to were: are, was, have, had, be, while, those, been,
# Nearest to been: become, be, was, were, recently, already, had, previously,
# Average loss at step 72000: 3.375990
# Average loss at step 74000: 3.349694
# Average loss at step 76000: 3.318428
# Average loss at step 78000: 3.354874
# Average loss at step 80000: 3.378520
# Nearest to would: could, will, can, may, should, might, must, cannot,
# Nearest to see: according, depict, list, includes, but, governorate, kidd, hautes,
# Nearest to between: among, within, with, through, reeves, xenon, in, over,
# Nearest to its: their, his, her, the, baiting, referenda, incised, liberties,
# Nearest to such: well, these, follows, known, certain, cowardly, imine, mae,
# Nearest to zero: four, five, seven, six, eight, three, nine, u,
# Nearest to have: had, has, are, include, having, be, were, situational,
# Nearest to during: after, in, before, when, throughout, despite, until, although,
# Nearest to had: has, have, were, was, having, became, situational, did,
# Nearest to history: list, osage, schoolgirl, sdk, quadrangle, admin, groningen, greenland,
# Nearest to may: can, will, would, might, must, should, could, cannot,
# Nearest to new: lysosome, queensland, single, duchy, unfairness, bench, hydroponics, feeble,
# Nearest to they: we, he, there, you, she, it, who, not,
# Nearest to by: through, didgeridoo, ls, provincias, densely, when, brady, muay,
# Nearest to were: are, was, had, have, while, those, became, these,
# Nearest to been: become, be, recently, already, begun, was, previously, crackdown,
# Average loss at step 82000: 3.411175
# Average loss at step 84000: 3.409938
# Average loss at step 86000: 3.386066
# Average loss at step 88000: 3.348887
# Average loss at step 90000: 3.368441
# Nearest to would: could, will, can, may, might, should, must, cannot,
# Nearest to see: includes, list, according, drinkordie, references, hautes, rias, refer,
# Nearest to between: with, within, among, through, xenon, reeves, across, over,
# Nearest to its: their, his, her, the, divisive, baiting, whose, liberties,
# Nearest to such: well, these, known, follows, certain, cowardly, many, brimstone,
# Nearest to zero: five, seven, four, eight, six, nine, two, three,
# Nearest to have: had, has, are, were, be, include, having, stratofortress,
# Nearest to during: after, in, throughout, before, until, despite, although, at,
# Nearest to had: have, has, were, was, having, been, sutra, situational,
# Nearest to history: list, admin, groningen, midi, schoolgirl, venerable, uzbeks, author,
# Nearest to may: can, must, might, could, should, would, will, cannot,
# Nearest to new: duchy, musical, bench, unfairness, queensland, particular, cretan, quarrel,
# Nearest to they: we, he, there, you, she, it, who, these,
# Nearest to by: through, under, brady, without, when, during, didgeridoo, using,
# Nearest to were: are, had, was, have, while, although, these, those,
# Nearest to been: become, be, already, was, being, previously, had, recently,
# Average loss at step 92000: 3.392347
# Average loss at step 94000: 3.253327
# Average loss at step 96000: 3.361861
# Average loss at step 98000: 3.247954
# Average loss at step 100000: 3.358977
# Nearest to would: will, could, can, may, should, might, must, cannot,
# Nearest to see: includes, list, references, according, external, rias, hautes, inlet,
# Nearest to between: among, within, through, with, reeves, xenon, over, pilsner,
# Nearest to its: their, his, the, her, liberties, polygons, baiting, utraquists,
# Nearest to such: known, well, these, follows, certain, many, mae, cowardly,
# Nearest to zero: five, four, seven, eight, six, nine, three, two,
# Nearest to have: had, has, include, were, are, produce, having, tend,
# Nearest to during: in, after, throughout, before, despite, until, following, when,
# Nearest to had: has, have, having, was, were, would, did, could,
# Nearest to history: list, admin, uzbeks, clay, solent, maha, review, pedagogue,
# Nearest to may: can, should, could, must, might, would, will, cannot,
# Nearest to new: single, different, hoist, duchy, particular, musical, mackey, unfairness,
# Nearest to they: we, he, there, you, it, she, i, these,
# Nearest to by: brady, chu, when, using, under, densely, through, didgeridoo,
# Nearest to were: are, these, have, was, those, had, unsaturated, remain,
# Nearest to been: become, be, already, was, recently, previously, crooked, had,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
# https://cs224d.stanford.edu/lecture_notes/notes1.pdf

# %%
data_index = 0

def generate_batch(batch_size, window):
    global data_index
    context = 2 * window
    batch = np.ndarray(shape=(batch_size, context), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    span = 2 * window + 1
    buffer = collections.deque(maxlen=span)
    for _ in range(span):
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    for i in range(batch_size):
        batch[i, :] = [token for idx, token in enumerate(buffer) if idx != window]
        labels[i, 0] = buffer[window]
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    return batch, labels

demo_batch=10
print('data:', [reverse_dictionary[di] for di in data[:demo_batch]])

demo_window=2

batch, labels = generate_batch(batch_size=demo_batch, window=demo_window)
for i in range(demo_batch):
    l = ""
    for w in range(demo_window*2):
        l+=str(batch[i,w]) + " " + str(reverse_dictionary[batch[i,w]]) + " "
    print(labels[i], reverse_dictionary[labels[i,0]], '|', l)
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against']
# [12] as | 5243 anarchism 3081 originated 6 a 195 term
# [6] a | 3081 originated 12 as 195 term 2 of
# [195] term | 12 as 6 a 2 of 3134 abuse
# [2] of | 6 a 195 term 3134 abuse 46 first
# [3134] abuse | 195 term 2 of 46 first 59 used
# [46] first | 2 of 3134 abuse 59 used 156 against
# [59] used | 3134 abuse 46 first 156 against 128 early
# [156] against | 46 first 59 used 128 early 742 working
# [128] early | 59 used 156 against 742 working 477 class
# [742] working | 156 against 128 early 477 class 10605 radicals

# %%
graph = tf.Graph()

window = 8

with graph.as_default(), tf.device('/cpu:0'):
    # Input data.
    train_dataset = tf.placeholder(tf.int32, shape=[batch_size, window])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
    # Variables.
    embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
    softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
    # Model.
    # Look up embeddings for inputs.
    embed = tf.nn.embedding_lookup(embeddings, train_dataset)
    
    embed_context = tf.reduce_mean(embed, 1)
    
    loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed_context,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))


    # Construct the SGD optimizer using a learning rate of 1.0.
    optimizer = tf.train.GradientDescentOptimizer(1.0).minimize(loss)

    # Compute the cosine similarity between minibatch examples and all embeddings.
    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
    normalized_embeddings = embeddings / norm
    valid_embeddings = tf.nn.embedding_lookup(
        normalized_embeddings, valid_dataset)
    similarity = tf.matmul(
        valid_embeddings, normalized_embeddings, transpose_b=True)

    # Add variable initializer.
    init = tf.global_variables_initializer

# %%
def train_cbow():
    num_steps = 100001

    with tf.Session(graph=graph) as session:
      tf.global_variables_initializer().run()
      print('Initialized')
      average_loss = 0
      for step in range(num_steps):
        batch_data, batch_labels = generate_batch(
          batch_size, window=window/2)
        feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
        _, l = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += l
        if step % 2000 == 0:
          if step > 0:
            average_loss = average_loss / 2000
          # The average loss is an estimate of the loss over the last 2000 batches.
          print('Average loss at step %d: %f' % (step, average_loss))
          average_loss = 0
        # note that this is expensive (~20% slowdown if computed every 500 steps)
        if step % 10000 == 0:
          sim = similarity.eval()
          for i in range(valid_size):
            valid_word = reverse_dictionary[valid_examples[i]]
            top_k = 8 # number of nearest neighbors
            nearest = (-sim[i, :]).argsort()[1:top_k+1]
            log = 'Nearest to %s:' % valid_word
            for k in range(top_k):
              close_word = reverse_dictionary[nearest[k]]
              log = '%s %s,' % (log, close_word)
            print(log)
      return normalized_embeddings.eval()
final_embeddings=train_cbow()
# Out:
# Initialized
# Average loss at step 0: 6.802913
# Nearest to would: sobriquet, covenants, cozy, gail, urgell, telescope, montane, decibels,
# Nearest to see: jogaila, indentation, wladislaus, contaminated, erasable, admiralty, hu, tsing,
# Nearest to between: cigars, mediterranean, locale, nutrients, balloons, mboxx, reprinting, curl,
# Nearest to its: requiem, geldof, arterial, splice, metaphysical, undesired, mediaeval, schuschnigg,
# Nearest to such: khmelnytsky, videotaped, interrelated, eau, danny, auditioning, excused, tatar,
# Nearest to zero: birthright, notably, semiology, royalist, ifn, inn, injection, retro,
# Nearest to have: alliance, exodus, janus, reginald, unbroken, cheshire, folders, automation,
# Nearest to during: acquitted, correspondance, wanna, henze, instinctively, reichswehr, preserves, acidosis,
# Nearest to had: ebooks, feelin, maimon, sceptre, priests, cartels, eyesight, pets,
# Nearest to history: role, walruses, hydroelectricity, behest, vat, verne, telekinesis, employees,
# Nearest to may: helicopter, wander, christological, remarking, abol, hrer, cleaner, beja,
# Nearest to new: hasn, raphael, funerals, fallen, discern, purposes, eubank, spoilers,
# Nearest to they: vide, cen, merlin, sex, swami, reprisals, pathways, etruscans,
# Nearest to by: brahmin, raping, dudayev, flockhart, bloodless, walkway, hani, eubank,
# Nearest to were: etruscan, cars, crops, vale, tokugawa, ewell, ferret, topics,
# Nearest to been: rheumatism, kjv, birthday, hinayana, cockburn, ethica, foster, na,
# Average loss at step 2000: 4.737810
# Average loss at step 4000: 4.077304
# Average loss at step 6000: 3.896719
# Average loss at step 8000: 3.725838
# Average loss at step 10000: 3.760515
# Nearest to would: covenants, approximately, sobriquet, fabricius, liberia, urgell, recursive, cozy,
# Nearest to see: jogaila, wladislaus, indentation, their, namespace, tsing, contaminated, unitarian,
# Nearest to between: cigars, mboxx, lilac, cad, commander, folktales, mediterranean, humor,
# Nearest to its: dealers, arterial, requiem, received, whiz, religion, genital, amidst,
# Nearest to such: interrelated, bani, he, excused, gamsakhurdia, possible, illuminate, remission,
# Nearest to zero: inn, since, ifn, semiology, injection, two, about, carnage,
# Nearest to have: had, be, folders, sukhum, has, alliance, reginald, valve,
# Nearest to during: acquitted, wanna, instinctively, correspondance, reichswehr, preserves, thibetanus, border,
# Nearest to had: have, are, has, but, sceptre, officer, feelin, maimon,
# Nearest to history: role, hydroelectricity, walruses, telekinesis, vat, verne, monastery, bentsen,
# Nearest to may: remarking, helicopter, abol, editorial, christological, hrer, offender, bloc,
# Nearest to new: fallen, concerning, raphael, hasn, spoilers, purposes, enzo, excursion,
# Nearest to they: but, been, unique, eleven, reprisals, sex, rodney, for,
# Nearest to by: with, that, for, as, in, to, which, or,
# Nearest to were: tokugawa, are, garter, lockout, was, oda, he, crops,
# Nearest to been: no, kjv, they, hinayana, foster, rheumatism, birthday, cockburn,
# Average loss at step 12000: 3.732008
# Average loss at step 14000: 3.705325
# Average loss at step 16000: 3.724627
# Average loss at step 18000: 3.656577
# Average loss at step 20000: 3.660080
# Nearest to would: has, can, to, covenants, may, recursive, fabricius, approximately,
# Nearest to see: jogaila, wladislaus, indentation, their, namespace, an, contaminated, tsing,
# Nearest to between: cigars, mboxx, revitalize, lilac, cad, humor, angst, squares,
# Nearest to its: this, dealers, received, but, the, it, whiz, an,
# Nearest to such: possible, interrelated, excused, gamsakhurdia, well, bani, donny, illuminate,
# Nearest to zero: inn, ifn, since, accompanying, semiology, about, carnage, injection,
# Nearest to have: had, has, be, are, sukhum, alliance, reginald, folders,
# Nearest to during: acquitted, at, thibetanus, wanna, instinctively, goku, forecasting, reichswehr,
# Nearest to had: have, has, are, were, was, but, would, officer,
# Nearest to history: role, hydroelectricity, bentsen, telekinesis, speculative, vat, monastery, verne,
# Nearest to may: remarking, can, helicopter, editorial, offender, would, hrer, abol,
# Nearest to new: fallen, concerning, enzo, forming, purposes, spoilers, excursion, poole,
# Nearest to they: but, not, eleven, sex, been, reprisals, unique, trombonist,
# Nearest to by: with, that, which, for, scullin, natural, spectroscopy, souvenirs,
# Nearest to were: are, was, had, lockout, garter, observation, tokugawa, predictions,
# Nearest to been: no, kjv, foster, hinayana, they, cockburn, rheumatism, birthday,
# Average loss at step 22000: 3.648605
# Average loss at step 24000: 3.621264
# Average loss at step 26000: 3.606933
# Average loss at step 28000: 3.622902
# Average loss at step 30000: 3.591092
# Nearest to would: can, could, will, may, should, to, has, had,
# Nearest to see: jogaila, wladislaus, indentation, namespace, contaminated, their, an, tsing,
# Nearest to between: cigars, into, revitalize, of, mboxx, lilac, protesters, angst,
# Nearest to its: this, their, the, dealers, an, his, received, it,
# Nearest to such: well, possible, excused, gamsakhurdia, interrelated, known, donny, bani,
# Nearest to zero: accompanying, five, semiology, inn, perkins, injection, carnage, about,
# Nearest to have: had, has, be, are, sukhum, were, alliance, million,
# Nearest to during: at, acquitted, thibetanus, goku, forecasting, wanna, instinctively, under,
# Nearest to had: has, have, were, was, are, would, vladivostok, noumenon,
# Nearest to history: telekinesis, role, hydroelectricity, bentsen, speculative, refrigerated, throwers, university,
# Nearest to may: can, would, should, remarking, could, helicopter, offender, editorial,
# Nearest to new: fallen, concerning, forming, enzo, purposes, spoilers, excursion, poole,
# Nearest to they: but, eleven, not, trombonist, sex, these, if, rodney,
# Nearest to by: with, into, spectroscopy, natural, scullin, souvenirs, khanty, euboea,
# Nearest to were: are, was, had, have, christian, predictions, lockout, observation,
# Nearest to been: no, kjv, foster, hinayana, cockburn, birthday, discreetly, rheumatism,
# Average loss at step 32000: 3.538832
# Average loss at step 34000: 3.566836
# Average loss at step 36000: 3.569168
# Average loss at step 38000: 3.518465
# Average loss at step 40000: 3.577377
# Nearest to would: will, can, could, should, may, to, must, has,
# Nearest to see: jogaila, wladislaus, namespace, contaminated, indentation, decoration, tsing, hydronium,
# Nearest to between: into, cigars, of, revitalize, with, jason, protesters, mboxx,
# Nearest to its: this, their, the, dealers, an, tarragona, angels, his,
# Nearest to such: well, possible, known, excused, gamsakhurdia, interrelated, donny, illuminate,
# Nearest to zero: accompanying, semiology, inn, five, carnage, kierkegaard, ifn, injection,
# Nearest to have: had, has, be, are, were, sukhum, million, punks,
# Nearest to during: goku, thibetanus, at, under, acquitted, forecasting, game, wanna,
# Nearest to had: has, have, were, was, would, are, exalted, vladivostok,
# Nearest to history: speculative, hydroelectricity, bentsen, role, telekinesis, throwers, university, theory,
# Nearest to may: can, should, would, could, will, must, remarking, offender,
# Nearest to new: fallen, concerning, forming, enzo, purposes, poole, hammering, nellis,
# Nearest to they: these, eleven, but, trombonist, sex, not, rodney, omissions,
# Nearest to by: with, spectroscopy, into, scullin, natural, souvenirs, euboea, khanty,
# Nearest to were: are, was, had, have, predictions, christian, lockout, observation,
# Nearest to been: no, kjv, hinayana, foster, cockburn, discreetly, teg, birthday,
# Average loss at step 42000: 3.556111
# Average loss at step 44000: 3.538876
# Average loss at step 46000: 3.529176
# Average loss at step 48000: 3.486412
# Average loss at step 50000: 3.514250
# Nearest to would: will, could, should, can, may, must, to, noted,
# Nearest to see: jogaila, wladislaus, contaminated, namespace, decoration, indentation, sonatas, erasable,
# Nearest to between: into, cigars, of, revitalize, with, jason, protesters, quetzalcoatl,
# Nearest to its: their, this, the, dealers, tarragona, angels, whiz, corinne,
# Nearest to such: well, possible, excused, known, gamsakhurdia, interrelated, bani, illuminate,
# Nearest to zero: accompanying, warned, kierkegaard, inn, umts, semiology, perkins, injection,
# Nearest to have: had, has, be, are, were, million, sukhum, punks,
# Nearest to during: goku, under, thibetanus, at, forecasting, acquitted, through, game,
# Nearest to had: has, have, were, was, would, exalted, vladivostok, noumenon,
# Nearest to history: speculative, hydroelectricity, bentsen, role, telekinesis, throwers, university, theory,
# Nearest to may: can, should, would, could, must, will, remarking, offender,
# Nearest to new: fallen, forming, concerning, enzo, hammering, villagers, poole, purposes,
# Nearest to they: eleven, these, trombonist, rodney, omissions, sex, but, so,
# Nearest to by: spectroscopy, scullin, with, souvenirs, euboea, natural, into, nuncio,
# Nearest to were: are, was, had, have, predictions, christian, beatified, lockout,
# Nearest to been: no, cockburn, kjv, hinayana, foster, discreetly, teg, propel,
# Average loss at step 52000: 3.517501
# Average loss at step 54000: 3.444704
# Average loss at step 56000: 3.479857
# Average loss at step 58000: 3.485483
# Average loss at step 60000: 3.453788
# Nearest to would: will, could, should, can, may, must, cannot, to,
# Nearest to see: jogaila, wladislaus, contaminated, decoration, namespace, indentation, sonatas, promenade,
# Nearest to between: into, with, jason, cigars, revitalize, of, among, quetzalcoatl,
# Nearest to its: their, this, the, dealers, tarragona, angels, teschen, corinne,
# Nearest to such: well, excused, possible, gamsakhurdia, known, interrelated, bani, cordless,
# Nearest to zero: five, accompanying, semiology, inn, perkins, kierkegaard, million, umts,
# Nearest to have: had, has, be, are, were, sukhum, million, punks,
# Nearest to during: under, goku, thibetanus, within, through, since, forecasting, at,
# Nearest to had: has, have, were, was, would, exalted, hotels, feelin,
# Nearest to history: speculative, role, hydroelectricity, university, bentsen, theory, throwers, telekinesis,
# Nearest to may: can, should, could, would, must, will, cannot, might,
# Nearest to new: concerning, fallen, forming, enzo, villagers, hammering, pacified, poole,
# Nearest to they: these, trombonist, eleven, rodney, omissions, sex, them, you,
# Nearest to by: spectroscopy, scullin, undeveloped, euboea, souvenirs, babysitter, elegant, natural,
# Nearest to were: are, was, had, have, predictions, bulldog, specifies, christian,
# Nearest to been: hinayana, no, cockburn, kjv, foster, teg, discreetly, nurses,
# Average loss at step 62000: 3.424270
# Average loss at step 64000: 3.417290
# Average loss at step 66000: 3.395981
# Average loss at step 68000: 3.461809
# Average loss at step 70000: 3.425451
# Nearest to would: will, could, should, may, can, must, cannot, might,
# Nearest to see: jogaila, wladislaus, decoration, contaminated, namespace, indentation, promenade, sonatas,
# Nearest to between: into, with, jason, revitalize, cigars, among, of, quetzalcoatl,
# Nearest to its: their, this, the, dealers, angels, tarragona, corinne, teschen,
# Nearest to such: well, possible, excused, gamsakhurdia, known, regarded, baen, interrelated,
# Nearest to zero: five, million, semiology, inn, accompanying, umts, kierkegaard, perkins,
# Nearest to have: had, has, are, be, were, include, million, exchangeable,
# Nearest to during: under, goku, thibetanus, within, through, since, forecasting, old,
# Nearest to had: has, have, were, was, would, exalted, feelin, hotels,
# Nearest to history: role, speculative, hydroelectricity, university, theory, throwers, telekinesis, bentsen,
# Nearest to may: can, should, could, would, must, will, cannot, might,
# Nearest to new: forming, concerning, enzo, fallen, villagers, hammering, pacified, funerals,
# Nearest to they: these, trombonist, rodney, eleven, we, you, omissions, sex,
# Nearest to by: spectroscopy, scullin, souvenirs, undeveloped, khanty, babysitter, elegant, euboea,
# Nearest to were: are, was, had, have, predictions, bulldog, maquis, beatified,
# Nearest to been: hinayana, cockburn, teg, kjv, foster, discreetly, become, no,
# Average loss at step 72000: 3.386274
# Average loss at step 74000: 3.452642
# Average loss at step 76000: 3.453570
# Average loss at step 78000: 3.369349
# Average loss at step 80000: 3.428995
# Nearest to would: will, could, should, may, must, can, cannot, might,
# Nearest to see: jogaila, wladislaus, decoration, contaminated, promenade, namespace, sonatas, salinity,
# Nearest to between: into, both, with, jason, among, revitalize, quetzalcoatl, cigars,
# Nearest to its: their, the, this, dealers, angels, tarragona, corinne, teschen,
# Nearest to such: well, possible, excused, gamsakhurdia, regarded, baen, known, cordless,
# Nearest to zero: inn, five, million, semiology, umts, kierkegaard, accompanying, omari,
# Nearest to have: had, has, be, are, were, include, exchangeable, kiribati,
# Nearest to during: under, goku, within, through, thibetanus, following, since, forecasting,
# Nearest to had: has, have, were, was, would, exalted, hotels, intermediaries,
# Nearest to history: university, speculative, list, hydroelectricity, throwers, role, theory, modern,
# Nearest to may: should, can, could, would, must, will, cannot, might,
# Nearest to new: concerning, forming, villagers, enzo, fallen, hammering, pacified, funerals,
# Nearest to they: trombonist, these, we, you, rodney, eleven, rdx, sex,
# Nearest to by: spectroscopy, scullin, undeveloped, souvenirs, babysitter, euboea, elegant, khanty,
# Nearest to were: are, was, had, have, predictions, maquis, bulldog, christian,
# Nearest to been: hinayana, teg, cockburn, become, kjv, discreetly, foster, heated,
# Average loss at step 82000: 3.398628
# Average loss at step 84000: 3.417331
# Average loss at step 86000: 3.406844
# Average loss at step 88000: 3.358625
# Average loss at step 90000: 3.361003
# Nearest to would: will, could, should, may, must, can, cannot, might,
# Nearest to see: jogaila, wladislaus, decoration, contaminated, promenade, namespace, sonatas, entablature,
# Nearest to between: into, both, with, jason, among, revitalize, over, quetzalcoatl,
# Nearest to its: their, the, this, angels, dealers, tarragona, corinne, our,
# Nearest to such: well, possible, excused, regarded, gamsakhurdia, baen, carburetor, result,
# Nearest to zero: omari, inn, kierkegaard, accompanying, umts, warned, u, redrawing,
# Nearest to have: had, has, are, were, be, include, exchangeable, lvarez,
# Nearest to during: within, goku, under, through, thibetanus, throughout, since, old,
# Nearest to had: has, have, were, was, would, hotels, exalted, priests,
# Nearest to history: list, university, speculative, modern, throwers, hydroelectricity, encyclopedia, theory,
# Nearest to may: can, should, could, must, would, will, cannot, might,
# Nearest to new: concerning, villagers, forming, enzo, hammering, raphael, pacified, fallen,
# Nearest to they: we, you, trombonist, these, rodney, eleven, rdx, sex,
# Nearest to by: scullin, spectroscopy, undeveloped, souvenirs, babysitter, khanty, euboea, hated,
# Nearest to were: are, was, had, have, maquis, predictions, bulldog, beatified,
# Nearest to been: become, hinayana, teg, cockburn, discreetly, kjv, foster, continuance,
# Average loss at step 92000: 3.376559
# Average loss at step 94000: 3.117744
# Average loss at step 96000: 3.189115
# Average loss at step 98000: 3.331622
# Average loss at step 100000: 3.345318
# Nearest to would: will, could, should, may, must, can, cannot, might,
# Nearest to see: decoration, wladislaus, contaminated, jogaila, promenade, entablature, sonatas, namespace,
# Nearest to between: into, both, among, with, jason, revitalize, over, abdicate,
# Nearest to its: their, the, this, angels, dealers, corinne, tarragona, our,
# Nearest to such: well, regarded, possible, excused, gamsakhurdia, result, carburetor, baen,
# Nearest to zero: million, inn, omari, accompanying, u, kierkegaard, approximately, mahoney,
# Nearest to have: had, has, be, are, lvarez, exchangeable, kiribati, include,
# Nearest to during: within, under, goku, throughout, through, following, thibetanus, old,
# Nearest to had: has, have, were, was, would, priests, hotels, exalted,
# Nearest to history: modern, university, list, speculative, encyclopedia, hydroelectricity, throwers, role,
# Nearest to may: should, can, could, must, would, will, might, cannot,
# Nearest to new: concerning, villagers, enzo, forming, pacified, raphael, hammering, herein,
# Nearest to they: you, we, trombonist, eleven, rodney, these, rdx, omissions,
# Nearest to by: spectroscopy, scullin, undeveloped, souvenirs, khanty, cherries, streamline, hated,
# Nearest to were: are, was, had, maquis, have, predictions, bulldog, beatified,
# Nearest to been: become, hinayana, teg, discreetly, cockburn, kjv, foster, padded,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
plot(two_d_embeddings, words)
